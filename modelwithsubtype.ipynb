# %%
import sctop as top
import pandas as pd
from taigapy import create_taiga_client_v3
import numpy as np
import io
import os
import seaborn as sns

from numpy.random import default_rng

rng = default_rng(2024)

tc = create_taiga_client_v3()
import matplotlib.pyplot as plt

# %%
class OrderParamClassifier:
    def __init__(self, expr, markers, num_samples):
        """

        :param expr: Expression data.
            Format: Pandas DataFrame.
            Rows: samples (index)
            Columns: genes (ensg).
            Entries: log2(tpm+1)
        :param markers: Cell types
            Format: Pandas Series
            Rows: samples (index)
            Columns: metadata
            Entries: plain text. at least one cell/disease type column
        :param num_samples: Int. Number of samples to take from each marker for training

        """
        self.expr = expr
        self.markers = markers
        self.num_samples = num_samples
        self.basis = pd.DataFrame()

        self.harmonize_samples()

    def load_expr(self):
        pass

    def load_meta(self):
        pass

    def harmonize_samples(self):
        shared_idxs = self.expr.index.intersection(self.markers.index)
        self.expr = self.expr.loc[shared_idxs]
        self.markers = self.markers.loc[shared_idxs]

        marker_counts = self.markers.value_counts()
        valid_markers = marker_counts[marker_counts > self.num_samples].index
        self.markers = self.markers[self.markers.isin(valid_markers)]

    def train(self):
        expr_list = []
        train_ids = []

        labels = self.markers.unique().tolist()

        for curr_type in labels:
            curr_type_ids = self.markers[self.markers == curr_type].index
            train_sample = rng.choice(curr_type_ids, self.num_samples, replace=False)
            train_ids += [train_sample]

            curr_expr = self.expr.loc[train_sample]
            curr_processed = top.process(2 ** curr_expr.T - 1, average=True)
            expr_list.append(curr_processed)

        train_ids = np.concatenate(train_ids)
        self.basis = pd.concat(expr_list, axis=1)
        self.basis.columns = labels
        self.basis.index = self.basis.index.rename('gene')

        accuracies, test_labels, projections, eta = self.validate_training(train_ids)
        return train_ids, accuracies, test_labels, projections, eta

    def score(self, test_data):
        processed = top.process(2 ** test_data.T - 1)
        projections, _, eta = top.score(self.basis, processed, full_output=True)
        return projections, eta

    def validate_training(self, train_ids):
        test_ids = self.markers.index.difference(self.markers.loc[train_ids].index)
        projections, eta = self.score(self.expr.loc[test_ids])

        return self.check_acc(projections) + (projections, eta)

    def check_acc(self, projections, skip_fun=None, specification_value=0.1):
        if not skip_fun:
            def skip_fun(sample, ann):
                return False

        accuracies = {'top1': 0,
                      'top3': 0,
                      'unspecified': 0
                      }

        num_tested = 0

        labels = []

        for sample_id, sample_projections in projections.iteritems():

            types_sorted_by_projections = sample_projections.sort_values(ascending=False).index
            true_type = self.markers.loc[sample_id]

            if skip_fun(sample_id, self.markers):
                continue

            num_tested += 1

            top_type = types_sorted_by_projections[0]

            if sample_projections.max() < specification_value:
                accuracies['unspecified'] += 1

            if top_type == true_type:
                accuracies['top1'] += 1
            if true_type in types_sorted_by_projections[:3]:
                accuracies['top3'] += 1

            true_idx_tup = (true_type, true_type, true_type)
            label_df = pd.DataFrame(data=true_idx_tup, columns=['true_type'])
            label_df['labeled_type'] = types_sorted_by_projections[:3]
            label_df.index.name = 'place'
            labels.append(label_df.reset_index())

        print('Accuracy statistics for {} test samples and {} training samples per cancer type'.format(num_tested,
                                                                                                       self.num_samples))

        for key, value in accuracies.items():
            print('{}: {:.2f}%'.format(key, 100 * value / num_tested))

        return accuracies, pd.concat(labels, ignore_index=True)


def get_gene_map(tc, get_transcripts=False):
    hgnc = tc.get(name='hgnc-87ab', version=7, file='hgnc_complete_set')
    hgnc = hgnc[['hgnc_id', 'symbol', 'locus_group', 'locus_type', 'entrez_id', 'ensembl_gene_id']]
    hgnc['depmap'] = hgnc.symbol + ' (' + hgnc.entrez_id.fillna(-1).astype(int).astype(str) + ')'
    hgnc.loc[(hgnc.symbol.isna()) | (hgnc.entrez_id.isna()), 'depmap'] = np.nan
    if get_transcripts:
        ensembl = generateGeneNames(attributes=['ensembl_transcript_id'], cache_folder=os.getcwd() + '/ensemblecache/')
        print(ensembl)
        hgnc = pd.merge(hgnc,
                        ensembl.set_index('ensembl_gene_id').ensembl_transcript_id,
                        left_on='ensembl_gene_id', right_index=True)
    return hgnc


def get_tcga_classifier(num_samples, annots=None, marker=None):
    tcga_expr = tc.get('celligner-input-9827.1/tumor_expression').fillna(0)
    if annots is None:
        annots = tc.get('celligner-input-9827.7/tumor_annotations').set_index('sampleID')
    if marker is None:
        tcga_ann = annots.oncotree_lineage
    else:
        tcga_ann = annots[marker]

    cfier = OrderParamClassifier(tcga_expr, tcga_ann, num_samples)
    return cfier


oncotree = tc.get(name="oncotree-42c7", version=1, file="oncotree").set_index("code")
oncotree=oncotree.reset_index()

# Step 1: Find names with more than one unique OncoTree code
multiple_codes = oncotree.groupby('name')['code'].nunique()
names_with_multiple_codes = multiple_codes[multiple_codes > 1].index

# Step 2: Update the 'name' column in the oncotree DataFrame
def update_name(row):
    if row['name'] in names_with_multiple_codes:
        return f"{row['name']} ({row['tissue']})"
    return row['name']

oncotree['name'] = oncotree.apply(update_name, axis=1)
oncotree=oncotree.set_index('code')

    
def get_tcga_classifier_bysubtype(num_samples):
    tcga_expr = tc.get('celligner-input-9827.1/tumor_expression').fillna(0)
    tcga_meta=pd.read_csv('/Users/nabdirah/Project1/3TCGA.csv') # with the new mapped subtypes 
    
    tcga_ann = tcga_meta.set_index('sampleID').new_subtype 

    cfier = OrderParamClassifier(tcga_expr, tcga_ann, num_samples)
    return cfier
    


def get_gtext_classifier():
    pass



def generateGeneNames(
    ensemble_server="http://nov2020.archive.ensembl.org/biomart",
    useCache=False,
    cache_folder='/home/ubuntu/Documents/data/ensemblcache/',
    attributes=[],
    default_attr=[
        "ensembl_gene_id",
        "clone_based_ensembl_gene",
        "hgnc_symbol",
        "gene_biotype",
        "entrezgene_id",
    ],
):
    """generate a genelist dataframe from ensembl's biomart

    Args:
        ensemble_server ([type], optional): [description]. Defaults to ENSEMBL_SERVER_V.
        useCache (bool, optional): [description]. Defaults to False.
        cache_folder ([type], optional): [description]. Defaults to CACHE_PATH.

    Raises:
        ValueError: [description]

    Returns:
        [type]: [description]
    """
    assert cache_folder[-1] == "/"

    cache_folder = os.path.expanduser(cache_folder)
    createFoldersFor(cache_folder)
    cachefile = os.path.join(cache_folder, ".biomart.csv")
    if useCache & os.path.isfile(cachefile):
        print("fetching gene names from biomart cache")
        res = pd.read_csv(cachefile)
    else:
        print("downloading gene names from biomart")
        res = _fetchFromServer(ensemble_server, default_attr + attributes)
        res.to_csv(cachefile, index=False)

    res.columns = default_attr + attributes
    if type(res) is not type(pd.DataFrame()):
        raise ValueError("should be a dataframe")

    if "clone_based_ensembl_gene" in default_attr and "hgnc_symbol" in default_attr:
        res = res[~(res["clone_based_ensembl_gene"].isna() & res["hgnc_symbol"].isna())]
        res.loc[res[res.hgnc_symbol.isna()].index, "hgnc_symbol"] = res[
            res.hgnc_symbol.isna()
        ]["clone_based_ensembl_gene"]

    return res

def createFoldersFor(filepath):
    """
    will recursively create folders if needed until having all the folders required to save the file in this filepath
    """
    prevval = ""
    for val in os.path.expanduser(filepath).split("/")[:-1]:
        prevval += val + "/"
        if not os.path.exists(prevval):
            os.mkdir(prevval)

def _fetchFromServer(ensemble_server, attributes):
    # deferring the import until last possible moment because it's unclear
    # to me whether we are actually fetching data from biomart. (I don't think we should)
    from biomart import BiomartServer

    server = BiomartServer(ensemble_server)
    ensmbl = server.datasets["hsapiens_gene_ensembl"]
    res = pd.read_csv(
        io.StringIO(
            ensmbl.search({"attributes": attributes}, header=1).content.decode()
        ),
        sep="\t",
    )
    return res

# %%
tcga_meta=pd.read_csv('/Users/nabdirah/Project1/3TCGA.csv')

# %%
# Step 2: Update the 'name' column in the oncotree DataFrame
oncotree=oncotree.set_index('code')
def update_name(row):
    if row['name'] in names_with_multiple_codes:
        return f"{row['name']} ({row['tissue']})"
    return row['name']

oncotree['name'] = oncotree.apply(update_name, axis=1)
oncotree=oncotree.set_index('code')
glioma_row = oncotree.loc['GNOS']
glioma_row['name'] = 'glioma'
glioma_row.name = 'GNOS_1'
oncotree=pd.concat([oncotree,glioma_row.to_frame().T])
acute_Row=oncotree.loc['TLL']	
acute_Row['name'] = 'acute lymphoblastic leukemia'
acute_Row.name = 'TLL_1'
ocotree=pd.concat([oncotree,acute_Row.to_frame().T])

# %%
sample_sizes = 25
classifier = get_tcga_classifier_bysubtype(sample_sizes)

# %%
classifier.train()
# Out:
# /var/folders/p8/ns8k_3ds56130jc48rg_027h0000gp/T/ipykernel_56106/2875311688.py:88: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for sample_id, sample_projections in projections.iteritems():
# Accuracy statistics for 10478 test samples and 25 training samples per cancer type
# top1: 84.53%
# top3: 95.32%
# unspecified: 0.00%
# (array(['TH02_0085_S01', 'THR24_1970_S01', 'THR11_0245_S01',
#         'TCGA-19-2619-01', 'THR24_1976_S01', 'TCGA-TQ-A7RN-01',
#         'TCGA-DU-6392-01', 'TCGA-S9-A7J2-01', 'TCGA-27-1837-01',
#         'THR24_2028_S01', 'TCGA-DB-5277-01', 'TCGA-TQ-A7RO-01',
#         'TCGA-DB-A64S-01', 'THR24_2068_S01', 'THR11_0267_S01',
#         'THR24_1927_S01', 'TCGA-02-0055-01', 'THR13_0974_S01',
#         'TH02_0095_S01', 'TCGA-19-5960-01', 'TCGA-HT-7881-01',
#         'THR24_1997_S01', 'THR14_0303_S01', 'TCGA-19-2629-01',
#         'TCGA-DU-7300-01', 'TARGET-40-PATPBS-01A-01R', 'THR25_0635_S01',
#         'THR15_0348_S01', 'TH27_0703_S02', 'TARGET-40-PARFTG-01A-01R',
#         'TH38_1416_S02', 'THR15_0345_S01', 'TH03_0296_S01',
#         'TARGET-40-0A4I65-01A-01R', 'TH27_1273_S01', 'TH06_0630_S01',
#         'THR25_0637_S01', 'TH27_0698_S01', 'THR15_0356_S01',
#         'TARGET-40-PANSEN-01A-01R', 'TH06_0634_S01', 'THR24_2089_S01',
#         'THR15_0357_S01', 'THR31_0893_S01', 'TARGET-40-PARBGW-01A-01R',
#         'TH03_0027_S03', 'TARGET-40-PAKFVX-01A-01R',
#         'TARGET-40-0A4HMC-01A-01R', 'TH27_1413_S01',
#         'TARGET-40-PANXSC-01A-01R', 'THR33_1117_S01', 'THR33_1135_S01',
#         'THR33_1137_S01', 'THR33_0986_S01', 'THR20_0485_S01',
#         'THR32_0961_S01', 'THR18_0407_S01', 'THR33_1143_S01',
#         'THR24_2076_S01', 'THR20_0497_S01', 'THR33_1006_S01',
#         'THR33_1139_S01', 'THR20_0505_S01', 'THR20_0501_S01',
#         'THR17_0403_S01', 'THR33_0989_S01', 'THR18_0409_S01',
#         'THR20_0506_S01', 'THR20_0504_S01', 'THR20_0513_S01',
#         'THR20_0507_S01', 'THR20_0493_S01', 'THR20_0491_S01',
#         'THR33_0987_S01', 'THR20_0516_S01', 'THR24_1498_S01',
#         'THR24_1511_S01', 'THR24_1510_S01', 'THR24_1465_S01',
#         'THR24_1493_S02', 'THR24_1466_S01', 'THR24_1502_S01',
#         'THR24_1494_S01', 'THR24_1548_S01', 'THR24_1553_S01',
#         'THR24_1474_S01', 'THR24_1485_S01', 'THR24_1499_S01',
#         'THR24_1464_S01', 'THR24_1484_S01', 'THR24_1483_S01',
#         'THR24_1489_S01', 'THR24_1478_S01', 'THR24_1470_S01',
#         'THR24_1477_S01', 'THR24_1506_S01', 'THR24_1462_S01',
#         'THR24_1535_S01', 'THR24_1537_S01', 'THR24_1508_S01',
#         'THR31_0889_S01', 'THR24_2005_S01', 'THR24_1664_S01',
#         'THR24_1885_S01', 'THR24_1769_S01', 'THR24_1881_S01',
#         'THR24_2112_S01', 'THR24_1616_S01', 'THR24_1578_S01',
#         'THR24_2003_S01', 'THR24_2110_S01', 'THR24_1653_S01',
#         'THR24_1575_S01', 'THR24_2113_S01', 'THR24_1654_S01',
#         'THR24_1610_S01', 'THR24_1588_S01', 'THR24_1764_S01',
#         'THR24_1609_S01', 'THR24_2007_S01', 'THR24_1684_S01',
#         'TH27_1411_S01', 'THR24_1633_S01', 'THR24_1700_S01',
#         'THR24_1891_S01', 'THR29_0796_S01', 'TH34_1414_S01',
#         'THR31_0919_S01', 'THR28_0686_S01', 'THR29_0730_S01',
#         'THR29_0725_S01', 'THR29_0760_S01', 'THR29_0728_S01',
#         'TH06_1174_S01', 'TH34_1163_S01', 'THR29_0782_S01',
#         'THR29_0783_S01', 'THR29_0787_S01', 'THR29_0765_S01',
#         'THR29_0795_S01', 'THR29_0733_S01', 'TH34_1380_S02',
#         'THR29_0798_S01', 'THR29_0784_S01', 'THR29_0786_S01',
#         'THR29_0746_S01', 'THR29_0768_S01', 'TH34_1380_S01',
#         'THR29_0732_S01', 'THR29_0799_S01', 'THR24_2015_S01',
#         'THR08_0183_S01', 'TARGET-10-PAKSWW-03', 'THR24_1873_S01',
#         'THR24_1600_S01', 'TARGET-10-PAPVTA-04', 'TARGET-10-PAPSPG-04',
#         'TARGET-10-PANWYH-09', 'TARGET-10-PARFTR-04', 'THR08_0188_S01',
#         'THR24_1854_S01', 'THR08_0195_S01', 'THR24_1652_S01',
#         'TARGET-10-PASFXA-04', 'THR24_1863_S01', 'TARGET-10-PANUHA-09',
#         'TARGET-10-PAPZST-04', 'TARGET-10-PARJZZ-09', 'THR24_1853_S01',
#         'THR24_1646_S01', 'TARGET-10-PARBVI-04', 'TARGET-10-PASCIU-03',
#         'THR08_0175_S01', 'TARGET-10-PAPZNK-04', 'TARGET-10-PAPDUF-09',
#         'THR08_0218_S01', 'TARGET-20-PANGTF-09', 'TCGA-AB-2826-03',
#         'THR08_0216_S01', 'TCGA-AB-2967-03', 'TCGA-AB-2930-03',
#         'TARGET-20-PAPWHS-09', 'TARGET-20-PARDMG-09',
#         'TARGET-20-PASIEJ-09', 'TARGET-20-PANTPW-09', 'THR24_1728_S01',
#         'TCGA-AB-2840-03', 'TARGET-20-PARUBT-09', 'TARGET-20-PARYFN-03',
#         'TARGET-21-PANVPB-09', 'TCGA-AB-2834-03', 'TCGA-AB-2966-03',
#         'TARGET-20-PARUNX-04', 'TARGET-21-PATKWH-09',
#         'TARGET-20-PASWAJ-04', 'THR31_0909_S01', 'TCGA-AB-2977-03',
#         'TARGET-20-PASGWH-09', 'TCGA-AB-2857-03', 'TARGET-20-PARUUB-09',
#         'THR30_0848_S01', 'THR30_0834_S01', 'TH06_0615_S01',
#         'TH27_0696_S01', 'TH03_0106_S01', 'THR30_0839_S01',
#         'THR30_0840_S01', 'THR30_0864_S01', 'THR30_0831_S01',
#         'THR30_0855_S01', 'THR31_1384_S01', 'THR30_0844_S01',
#         'THR30_0857_S01', 'THR30_0852_S01', 'TH34_1162_S01',
#         'THR30_0819_S01', 'THR30_0849_S01', 'THR30_0832_S01',
#         'THR30_0824_S01', 'TH27_0691_S01', 'THR31_0937_S01',
#         'THR30_0827_S01', 'TH27_1247_S01', 'THR30_0823_S01',
#         'TH06_1171_S01', 'THR31_0882_S01', 'TARGET-30-PARZHA-01',
#         'TARGET-30-PAPTLV-01', 'TH06_0284_S01', 'TARGET-30-PASJZC-01',
#         'TARGET-30-PAPLSD-01', 'TARGET-30-PATDWN-01',
#         'TARGET-30-PAPBZI-01', 'TARGET-30-PASMNT-01',
#         'TARGET-30-PAPTDH-01', 'TARGET-30-PARJVP-01',
#         'TARGET-30-PASYPX-01', 'TARGET-30-PATDXC-01',
#         'TARGET-30-PASXGP-01', 'TARGET-30-PANRRW-01',
#         'TARGET-30-PAKYZS-01', 'TARGET-30-PAIXIF-01',
#         'TARGET-30-PAIPGU-01', 'TH06_0628_S01', 'TARGET-30-PANYGR-01',
#         'TH27_1356_S01', 'TARGET-30-PAKZRH-01', 'TARGET-30-PARDCK-01',
#         'TARGET-30-PASMJG-01', 'TARGET-30-PAMVRA-01', 'THR39_1360_S01',
#         'TCGA-WK-A8XT-01', 'TCGA-DX-AB3C-01', 'TCGA-X6-A8C7-01',
#         'THR39_1373_S01', 'THR39_1361_S01', 'THR39_1368_S01',
#         'THR39_1371_S01', 'TH03_0112_S02', 'THR31_1392_S01',
#         'THR39_1365_S01', 'THR39_1363_S01', 'TH27_0976_S01',
#         'THR39_1374_S01', 'THR39_1364_S01', 'TCGA-Z4-AAPF-01',
#         'THR39_1375_S01', 'THR31_1386_S01', 'TCGA-MJ-A850-01',
#         'THR39_1367_S01', 'THR39_1366_S01', 'THR39_1377_S01',
#         'THR39_1370_S01', 'THR31_1393_S01', 'THR39_1372_S01',
#         'TCGA-L5-A4OW-01', 'TCGA-FB-A5VM-01', 'TCGA-L5-A8NV-01',
#         'TCGA-IB-A7LX-01', 'TCGA-AH-6544-01', 'TCGA-IN-A6RL-01',
#         'TCGA-VQ-A8DV-01', 'TCGA-VQ-A8PD-01', 'TCGA-D5-5539-01',
#         'TCGA-BR-4255-01', 'TCGA-BR-8592-01', 'TCGA-JY-A93D-01',
#         'TCGA-BR-8058-01', 'TCGA-CG-4472-01', 'TCGA-D7-6520-01',
#         'TCGA-LB-A8F3-01', 'TCGA-CG-4443-01', 'TCGA-DY-A1H8-01',
#         'TCGA-HU-A4GJ-01', 'TCGA-CG-5719-01', 'TCGA-BR-6457-01',
#         'TCGA-VQ-A91V-01', 'TCGA-L5-A8NF-01', 'TCGA-VQ-AA68-01',
#         'TCGA-VQ-A8E0-01', 'TCGA-ES-A2HS-01', 'TCGA-2V-A95S-01',
#         'TCGA-CC-5258-01', 'TCGA-G3-A25V-01', 'TCGA-2Y-A9H6-01',
#         'TCGA-DD-AADS-01', 'TCGA-DD-A1EJ-01', 'TCGA-K7-AAU7-01',
#         'TCGA-DD-AAVY-01', 'TCGA-CC-A3M9-01', 'TCGA-DD-AAE7-01',
#         'TCGA-LG-A9QC-01', 'TCGA-DD-AA3A-01', 'TCGA-DD-A73F-01',
#         'TCGA-CC-A7IF-01', 'TCGA-DD-AADG-01', 'TCGA-EP-A26S-01',
#         'TCGA-ZS-A9CE-01', 'TCGA-CC-A7IE-01', 'TCGA-O8-A75V-01',
#         'TCGA-WX-AA47-01', 'TCGA-LG-A9QD-01', 'TCGA-2Y-A9HA-01',
#         'TCGA-DD-AACB-01', 'TCGA-DD-A1EB-01', 'TCGA-OR-A5LD-01',
#         'TCGA-OR-A5KV-01', 'TCGA-OR-A5JA-01', 'TCGA-OR-A5JT-01',
#         'TCGA-OR-A5K8-01', 'TCGA-OR-A5JJ-01', 'THR10_0237_S01',
#         'TCGA-P6-A5OF-01', 'THR31_0917_S01', 'TCGA-OR-A5J6-01',
#         'TCGA-OR-A5JM-01', 'TCGA-OR-A5JE-01', 'TCGA-OR-A5LJ-01',
#         'TCGA-P6-A5OG-01', 'TCGA-OR-A5LB-01', 'THR10_0236_S01',
#         'TCGA-OR-A5LP-01', 'TCGA-OR-A5L8-01', 'TCGA-OR-A5KZ-01',
#         'TCGA-OR-A5K5-01', 'TCGA-OR-A5KT-01', 'TCGA-OR-A5J9-01',
#         'TCGA-OR-A5JC-01', 'THR24_1458_S01', 'TCGA-OR-A5KO-01',
#         'TCGA-A6-4105-01', 'TCGA-AD-6964-01', 'TCGA-DM-A28F-01',
#         'TCGA-QL-A97D-01', 'TCGA-F4-6703-01', 'TCGA-AA-3697-01',
#         'TCGA-F4-6805-01', 'TCGA-AU-6004-01', 'TCGA-G4-6299-01',
#         'TCGA-CK-5915-01', 'TCGA-A6-5666-01', 'TCGA-AA-3502-01',
#         'TCGA-A6-5657-01', 'TCGA-3L-AA1B-01', 'TCGA-CM-6163-01',
#         'TCGA-SS-A7HO-01', 'TCGA-D5-5541-01', 'TCGA-G4-6295-01',
#         'TCGA-D5-6922-01', 'TCGA-CM-6168-01', 'TCGA-AM-5820-01',
#         'TCGA-AA-A01X-01', 'TCGA-A6-5664-01', 'TCGA-G4-6314-01',
#         'TCGA-CM-6165-01', 'TCGA-73-4676-01', 'TCGA-05-4389-01',
#         'TCGA-L9-A8F4-01', 'TCGA-44-A47B-01', 'TCGA-55-1592-01',
#         'TCGA-95-7948-01', 'TCGA-MP-A4T9-01', 'TCGA-64-1676-01',
#         'TCGA-49-4514-01', 'TCGA-49-6761-01', 'TCGA-69-7760-01',
#         'TCGA-62-A46U-01', 'TCGA-97-A4M3-01', 'TCGA-55-6978-01',
#         'TCGA-MP-A4T4-01', 'TCGA-35-5375-01', 'TCGA-05-4425-01',
#         'TCGA-38-4629-01', 'TCGA-44-7659-01', 'TCGA-05-4396-01',
#         'TCGA-55-8205-01', 'TCGA-55-8301-01', 'TCGA-97-8179-01',
#         'TCGA-50-6591-01', 'TCGA-L9-A50W-01', 'TCGA-WE-AA9Y-06',
#         'TCGA-FW-A5DX-01', 'TCGA-D3-A1Q7-06', 'TCGA-FS-A4F4-06',
#         'TCGA-FR-A7UA-06', 'TCGA-D9-A1X3-06', 'TCGA-DA-A1IC-06',
#         'TCGA-EB-A4OZ-01', 'TCGA-EB-A24D-01', 'TCGA-GN-A268-06',
#         'TCGA-BF-A1Q0-01', 'TCGA-EE-A2GE-06', 'TCGA-WE-A8ZM-06',
#         'TCGA-DA-A1I8-06', 'TCGA-GN-A267-06', 'TCGA-DA-A1HY-06',
#         'TCGA-FS-A1ZA-06', 'TCGA-ER-A19T-01', 'TCGA-D9-A1JW-06',
#         'TCGA-EB-A6R0-01', 'TCGA-EE-A3AA-06', 'TCGA-D9-A3Z4-01',
#         'TCGA-EE-A29N-06', 'TCGA-ER-A42L-06', 'TCGA-D3-A1Q9-06',
#         'TCGA-DX-A6B8-01', 'TCGA-IE-A4EH-01', 'TCGA-DX-A6BA-01',
#         'TCGA-DX-A48U-01', 'TCGA-DX-A48K-01', 'TCGA-HB-A3L4-01',
#         'TCGA-DX-A6B9-01', 'TCGA-QQ-A8VF-01', 'TCGA-JV-A75J-01',
#         'TCGA-DX-A3UF-01', 'TCGA-X6-A8C5-01', 'TCGA-HS-A5NA-01',
#         'TCGA-JV-A5VF-01', 'TCGA-X6-A7WC-01', 'TCGA-FX-A3RE-01',
#         'TCGA-WK-A8XX-01', 'TCGA-JV-A5VE-01', 'TCGA-PC-A5DK-01',
#         'TCGA-K1-A6RV-01', 'TCGA-WK-A8XY-01', 'TCGA-IE-A4EK-01',
#         'TCGA-3B-A9I1-01', 'TCGA-3B-A9HP-01', 'TCGA-X9-A971-01',
#         'TCGA-MO-A47R-01', 'TCGA-BP-4988-01', 'TCGA-CJ-4912-01',
#         'TCGA-SX-A71R-01', 'TCGA-A4-A5DU-01', 'TCGA-CJ-4637-01',
#         'TCGA-CJ-5686-01', 'TCGA-CW-5581-01', 'TCGA-A4-7583-01',
#         'TCGA-HE-A5NK-01', 'TCGA-B0-5080-01', 'TCGA-A4-A4ZT-01',
#         'TCGA-B2-5636-01', 'TCGA-A4-7997-01', 'TCGA-MH-A562-01',
#         'TCGA-BP-4164-01', 'TCGA-B0-5115-01', 'TCGA-DZ-6132-01',
#         'TCGA-B9-A5W7-01', 'TCGA-DW-7839-01', 'TCGA-B0-4813-01',
#         'TCGA-CJ-4869-01', 'TCGA-EV-5901-01', 'TCGA-BP-4959-01',
#         'TCGA-CZ-4866-01', 'TCGA-A4-A48D-01', 'TCGA-WW-A8ZI-01',
#         'TCGA-YL-A9WJ-01', 'TCGA-CH-5740-01', 'TCGA-FC-7708-01',
#         'TCGA-J4-A67L-01', 'TCGA-HC-7752-01', 'TCGA-EJ-5512-01',
#         'TCGA-YL-A8HM-01', 'TCGA-HC-7080-01', 'TCGA-VP-A87C-01',
#         'TCGA-KK-A7AZ-01', 'TCGA-KC-A7FD-01', 'TCGA-XK-AAJT-01',
#         'TCGA-J9-A8CM-01', 'TCGA-XQ-A8TB-01', 'TCGA-G9-6336-01',
#         'TCGA-V1-A8ML-01', 'TCGA-EJ-A46H-01', 'TCGA-VN-A88Q-01',
#         'TCGA-HC-7211-01', 'TCGA-J4-8200-01', 'TCGA-VN-A88R-01',
#         'TCGA-VP-A876-01', 'TCGA-M7-A720-01', 'TCGA-KK-A59Y-01',
#         'TCGA-AJ-A3OK-01', 'TCGA-AJ-A3IA-01', 'TCGA-FI-A2EY-01',
#         'TCGA-PG-A915-01', 'TCGA-BG-A3PP-01', 'TCGA-PG-A914-01',
#         'TCGA-AJ-A3NH-01', 'TCGA-A5-A2K4-01', 'TCGA-EY-A4KR-01',
#         'TCGA-A5-A1OH-01', 'TCGA-B5-A1MS-01', 'TCGA-FI-A3PX-01',
#         'TCGA-BK-A26L-01', 'TCGA-FI-A3PV-01', 'TCGA-AJ-A3BF-01',
#         'TCGA-QS-A8F1-01', 'TCGA-AJ-A3NF-01', 'TCGA-EY-A3QX-01',
#         'TCGA-KP-A3W3-01', 'TCGA-JU-AAVI-01', 'TCGA-EO-A3KW-01',
#         'TCGA-KP-A3W4-01', 'TCGA-AX-A3GI-01', 'TCGA-B5-A0JN-01',
#         'TCGA-AX-A3G3-01', 'TCGA-D8-A73X-01', 'TCGA-HN-A2OB-01',
#         'TCGA-E9-A3Q9-01', 'TCGA-D8-A1JM-01', 'TCGA-B6-A3ZX-01',
#         'TCGA-AR-A0U2-01', 'TCGA-C8-A1HL-01', 'TCGA-B6-A0RM-01',
#         'TCGA-D8-A1X9-01', 'TCGA-AR-A1AW-01', 'TCGA-A7-A3IZ-01',
#         'TCGA-E9-A22B-01', 'TCGA-AN-A0FD-01', 'TCGA-C8-A12L-01',
#         'TCGA-BH-A18I-01', 'TCGA-BH-A18H-01', 'TCGA-OL-A66I-01',
#         'TCGA-A7-A0DB-01', 'TCGA-5L-AAT0-01', 'TCGA-BH-A0EA-01',
#         'TCGA-C8-A273-01', 'TCGA-AR-A24V-01', 'TCGA-AC-A23H-01',
#         'TCGA-A1-A0SH-01', 'TCGA-AR-A5QN-01', 'TCGA-77-8148-01',
#         'TCGA-P3-A6T5-01', 'TCGA-BB-7861-01', 'TCGA-Q1-A6DT-01',
#         'TCGA-EK-A2H0-01', 'TCGA-33-AASJ-01', 'TCGA-CV-A6JY-01',
#         'TCGA-34-5240-01', 'TCGA-66-2795-01', 'TCGA-LN-A49N-01',
#         'TCGA-33-6737-01', 'TCGA-94-8491-01', 'TCGA-77-7465-01',
#         'TCGA-CV-A464-01', 'TCGA-KU-A6H7-01', 'TCGA-EK-A2RK-01',
#         'TCGA-21-1078-01', 'TCGA-EA-A5FO-01', 'TCGA-ZJ-AAX8-01',
#         'TCGA-C5-A7X5-01', 'TCGA-Q1-A73S-01', 'TCGA-H7-8502-01',
#         'TCGA-63-A5MM-01', 'TCGA-C5-A2LT-01', 'TCGA-77-7141-01',
#         'TCGA-61-1728-01', 'TCGA-24-1562-01', 'TCGA-25-1328-01',
#         'TCGA-24-0979-01', 'TCGA-24-2298-01', 'TCGA-24-1552-01',
#         'TCGA-61-1743-01', 'TCGA-29-2427-01', 'TCGA-24-1544-01',
#         'TCGA-09-1662-01', 'TCGA-29-1762-01', 'TCGA-13-0916-01',
#         'TCGA-13-1482-01', 'TCGA-24-1103-01', 'TCGA-61-2009-01',
#         'TCGA-13-0800-01', 'TCGA-04-1343-01', 'TCGA-10-0933-01',
#         'TCGA-61-2003-01', 'TCGA-25-1623-01', 'TCGA-29-1707-02',
#         'TCGA-20-0987-01', 'TCGA-04-1542-01', 'TCGA-25-2409-01',
#         'TCGA-24-1546-01', 'TCGA-XU-AAY0-01', 'TCGA-XU-A92W-01',
#         'TCGA-ZB-A962-01', 'TCGA-XU-A92T-01', 'TCGA-X7-A8DJ-01',
#         'TCGA-XU-AAXW-01', 'TCGA-5K-AAAP-01', 'TCGA-ZB-A96P-01',
#         'TCGA-ZB-A96R-01', 'TCGA-XU-AAXY-01', 'TCGA-X7-A8DF-01',
#         'TCGA-3S-A8YW-01', 'TCGA-5U-AB0E-01', 'TCGA-X7-A8M4-01',
#         'TCGA-3G-AB0T-01', 'TCGA-ZB-A96K-01', 'TCGA-ZB-A96A-01',
#         'TCGA-4X-A9F9-01', 'TCGA-ZC-AAAH-01', 'TCGA-ZB-A96E-01',
#         'TCGA-4X-A9FB-01', 'TCGA-XU-A933-01', 'TCGA-XH-A853-01',
#         'TCGA-XU-A92Y-01', 'TCGA-4X-A9FD-01', 'TARGET-50-PAJMFY-01',
#         'TARGET-50-PAJNNR-01', 'TARGET-50-PALKRS-01',
#         'TARGET-50-PAJLTI-01', 'TARGET-50-PAJPDN-01',
#         'TARGET-50-PAJNCC-01', 'TARGET-50-PAJMXF-01',
#         'TARGET-50-PAKPDF-01', 'TARGET-50-PAJNDU-01',
#         'TARGET-50-CAAAAO-01', 'TARGET-50-PAJNZI-01',
#         'TARGET-50-PAKNXS-01', 'TARGET-50-PAKULH-01',
#         'TARGET-50-PAJPDC-01', 'TARGET-50-PAKRVH-01',
#         'TARGET-50-CAAAAS-01', 'TARGET-50-PAJNUP-01',
#         'TARGET-50-PAJMVC-01', 'TARGET-50-PAJMEN-01',
#         'TARGET-50-PALDTE-01', 'TARGET-50-PAKGMU-01',
#         'TARGET-50-PAJNNC-01', 'TARGET-50-PAJLPX-01',
#         'TARGET-50-PALGVY-01', 'TARGET-50-PAJMEL-01', 'TCGA-EM-A3O3-01',
#         'TCGA-DJ-A3UU-01', 'TCGA-DJ-A2PY-01', 'TCGA-DJ-A2Q3-01',
#         'TCGA-E8-A416-01', 'TCGA-EM-A3FO-01', 'TCGA-BJ-A18Y-01',
#         'TCGA-DJ-A13O-01', 'TCGA-BJ-A45C-01', 'TCGA-ET-A3BW-01',
#         'TCGA-ET-A25N-01', 'TCGA-EM-A3SZ-01', 'TCGA-FY-A3R7-01',
#         'TCGA-DJ-A3V5-01', 'TCGA-MK-A84Z-01', 'TCGA-DJ-A3V8-01',
#         'TCGA-DJ-A2Q1-01', 'TCGA-EM-A3O9-01', 'TCGA-ET-A3DR-01',
#         'TCGA-ET-A39I-01', 'TCGA-EM-A3AO-01', 'TCGA-EL-A4K6-01',
#         'TCGA-FY-A3W9-01', 'TCGA-FY-A2QD-01', 'TCGA-CE-A483-01',
#         'TCGA-K4-A83P-01', 'TCGA-DK-A6B2-01', 'TCGA-CF-A9FH-01',
#         'TCGA-CF-A27C-01', 'TCGA-ZF-AA4X-01', 'TCGA-K4-A3WV-01',
#         'TCGA-GV-A3JZ-01', 'TCGA-FD-A3SO-01', 'TCGA-E7-A85H-01',
#         'TCGA-XF-A9SH-01', 'TCGA-XF-AAMQ-01', 'TCGA-DK-A3X1-01',
#         'TCGA-FD-A3NA-01', 'TCGA-BL-A13I-01', 'TCGA-XF-AAMZ-01',
#         'TCGA-FD-A5C1-01', 'TCGA-G2-AA3B-01', 'TCGA-FD-A3B4-01',
#         'TCGA-YC-A8S6-01', 'TCGA-YF-AA3M-01', 'TCGA-ZF-AA4R-01',
#         'TCGA-BT-A20J-01', 'TCGA-UY-A9PB-01', 'TCGA-FD-A3SM-01',
#         'TCGA-BT-A20W-01', 'TCGA-ZN-A9VU-01', 'TCGA-LK-A4O2-01',
#         'TCGA-UT-A88E-01', 'TCGA-MQ-A4LJ-01', 'TCGA-TS-A8AF-01',
#         'TCGA-3H-AB3O-01', 'TCGA-UD-AABY-01', 'TCGA-SH-A9CU-01',
#         'TCGA-TS-A8AY-01', 'TCGA-MQ-A6BS-01', 'TCGA-UD-AAC4-01',
#         'TCGA-3U-A98E-01', 'TCGA-ZN-A9VS-01', 'TCGA-UT-A88D-01',
#         'TCGA-3H-AB3U-01', 'TCGA-3H-AB3M-01', 'TCGA-TS-A7OY-01',
#         'TCGA-TS-A7OZ-01', 'TCGA-SH-A9CT-01', 'TCGA-MQ-A6BN-01',
#         'TCGA-TS-A7P3-01', 'TCGA-3H-AB3S-01', 'TCGA-UD-AAC7-01',
#         'TCGA-LK-A4O4-01', 'TCGA-SH-A7BD-01', 'TCGA-AJ-A3EL-01',
#         'TCGA-A5-AB3J-01', 'TCGA-AX-A2IN-01', 'TCGA-A5-A7WJ-01',
#         'TCGA-SL-A6JA-01', 'TCGA-B5-A0JR-01', 'TCGA-5S-A9Q8-01',
#         'TCGA-EO-A1Y7-01', 'TCGA-A5-A2K5-01', 'TCGA-SL-A6J9-01',
#         'TCGA-BS-A0V7-01', 'TCGA-EO-A22Y-01', 'TCGA-B5-A3FB-01',
#         'TCGA-AX-A3FT-01', 'TCGA-AJ-A8CV-01', 'TCGA-B5-A0K9-01',
#         'TCGA-BK-A13B-01', 'TCGA-EO-A22X-01', 'TCGA-DI-A1C3-01',
#         'TCGA-EO-A3AV-01', 'TCGA-B5-A3FC-01', 'TCGA-BK-A4ZD-01',
#         'TCGA-AX-A3FS-01', 'TCGA-DF-A2KR-01', 'TCGA-4E-A92E-01',
#         'TCGA-VD-A8KB-01', 'TCGA-V4-A9ED-01', 'TCGA-VD-AA8N-01',
#         'TCGA-VD-A8KM-01', 'TCGA-V4-A9EJ-01', 'TCGA-V4-A9EU-01',
#         'TCGA-VD-A8KF-01', 'TCGA-V4-A9EM-01', 'TCGA-V4-A9EY-01',
#         'TCGA-V4-A9EO-01', 'TCGA-VD-A8KG-01', 'TCGA-V4-A9EQ-01',
#         'TCGA-VD-AA8Q-01', 'TCGA-V4-A9EA-01', 'TCGA-YZ-A983-01',
#         'TCGA-WC-AA9A-01', 'TCGA-VD-A8KD-01', 'TCGA-YZ-A984-01',
#         'TCGA-VD-AA8O-01', 'TCGA-V4-A9E8-01', 'TCGA-VD-A8KA-01',
#         'TCGA-V4-A9EK-01', 'TCGA-VD-A8K9-01', 'TCGA-V4-A9F5-01',
#         'TCGA-WC-A881-01', 'TCGA-N8-A4PQ-01', 'TCGA-NA-A4R1-01',
#         'TCGA-NA-A4R0-01', 'TCGA-N7-A4Y8-01', 'TCGA-N5-A4RM-01',
#         'TCGA-ND-A4WA-01', 'TCGA-N5-A4RO-01', 'TCGA-NF-A4WU-01',
#         'TCGA-N5-A4RD-01', 'TCGA-N6-A4VF-01', 'TCGA-N5-A4RS-01',
#         'TCGA-NA-A5I1-01', 'TCGA-QM-A5NM-01', 'TCGA-N5-A4R8-01',
#         'TCGA-NA-A4QW-01', 'TCGA-N8-A4PN-01', 'TCGA-N5-A4RF-01',
#         'TCGA-N9-A4Q4-01', 'TCGA-N6-A4V9-01', 'TCGA-N5-A59E-01',
#         'TCGA-N9-A4PZ-01', 'TCGA-NG-A4VW-01', 'TCGA-N8-A4PM-01',
#         'TCGA-NG-A4VU-01', 'TCGA-N6-A4VC-01', 'TCGA-KM-8440-01',
#         'TCGA-KN-8431-01', 'TCGA-KL-8331-01', 'TCGA-KO-8408-01',
#         'TCGA-KN-8432-01', 'TCGA-KL-8323-01', 'TCGA-KN-8423-01',
#         'TCGA-KL-8328-01', 'TCGA-KO-8407-01', 'TCGA-KN-8428-01',
#         'TCGA-KL-8325-01', 'TCGA-KM-8441-01', 'TCGA-KL-8334-01',
#         'TCGA-KL-8343-01', 'TCGA-KM-8443-01', 'TCGA-KN-8422-01',
#         'TCGA-KL-8345-01', 'TCGA-KO-8410-01', 'TCGA-KO-8405-01',
#         'TCGA-KN-8430-01', 'TCGA-KN-8424-01', 'TCGA-KL-8335-01',
#         'TCGA-KN-8433-01', 'TCGA-KL-8330-01', 'TCGA-KL-8341-01',
#         'TCGA-W5-AA2I-01', 'TCGA-W6-AA0S-01', 'TCGA-W5-AA38-01',
#         'TCGA-W5-AA2O-01', 'TCGA-ZH-A8Y5-01', 'TCGA-W5-AA31-01',
#         'TCGA-3X-AAV9-01', 'TCGA-W5-AA39-01', 'TCGA-W5-AA2Z-01',
#         'TCGA-ZH-A8Y1-01', 'TCGA-ZH-A8Y6-01', 'TCGA-W5-AA34-01',
#         'TCGA-ZH-A8Y4-01', 'TCGA-3X-AAVA-01', 'TCGA-W5-AA2U-01',
#         'TCGA-ZD-A8I3-01', 'TCGA-W5-AA30-01', 'TCGA-W5-AA2T-01',
#         'TCGA-ZH-A8Y8-01', 'TCGA-ZH-A8Y2-01', 'TCGA-3X-AAVE-01',
#         'TCGA-W5-AA33-01', 'TCGA-WD-A7RX-01', 'TCGA-W5-AA2R-01',
#         'TCGA-4G-AAZO-01', 'TCGA-G8-6909-01', 'TCGA-FF-A7CR-01',
#         'TCGA-GS-A9TT-01', 'TCGA-FA-A4XK-01', 'TCGA-FA-A7Q1-01',
#         'TCGA-G8-6324-01', 'TCGA-G8-6326-01', 'TCGA-FF-A7CX-01',
#         'TCGA-FA-A4BB-01', 'TCGA-FF-A7CQ-01', 'TCGA-GR-7351-01',
#         'TCGA-G8-6907-01', 'TCGA-FF-8042-01', 'TCGA-GR-A4D6-01',
#         'TCGA-GS-A9TZ-01', 'TCGA-GR-A4D9-01', 'TCGA-GS-A9TU-01',
#         'TCGA-RQ-A6JB-01', 'TCGA-FA-A6HN-01', 'TCGA-GR-A4D5-01',
#         'TCGA-FA-A6HO-01', 'TCGA-FF-A7CW-01', 'TCGA-GS-A9TV-01',
#         'TCGA-FF-8047-01', 'TCGA-FA-A82F-01'], dtype=object),
#  {'top1': 8857, 'top3': 9988, 'unspecified': 0},
#         place                          true_type  \
#  0          0  B-Lymphoblastic Leukemia/Lymphoma
#  1          1  B-Lymphoblastic Leukemia/Lymphoma
#  2          2  B-Lymphoblastic Leukemia/Lymphoma
#  3          0  B-Lymphoblastic Leukemia/Lymphoma
#  4          1  B-Lymphoblastic Leukemia/Lymphoma
#  ...      ...                                ...
#  31429      1                   Synovial Sarcoma
#  31430      2                   Synovial Sarcoma
#  31431      0                   Synovial Sarcoma
#  31432      1                   Synovial Sarcoma
#  31433      2                   Synovial Sarcoma
#
#                              labeled_type
#  0      B-Lymphoblastic Leukemia/Lymphoma
#  1           acute lymphoblastic leukemia
#  2                 Acute Myeloid Leukemia
#  3      B-Lymphoblastic Leukemia/Lymphoma
#  4                 Acute Myeloid Leukemia
#  ...                                  ...
#  31429                     Uveal Melanoma
#  31430               Colon Adenocarcinoma
#  31431                   Synovial Sarcoma
#  31432                     Uveal Melanoma
#  31433           Adrenocortical Carcinoma
#
#  [31434 rows x 3 columns],
#                                                      TARGET-10-PAMXHJ-09  \
#  CNS/Brain                                                     -0.046002
#  Osteosarcoma                                                  -0.026426
#  Medulloblastoma                                               -0.008276
#  Acute Megakaryoblastic Leukemia                               -0.006547
#  acute lymphoblastic leukemia                                   0.209443
#  Rhabdomyosarcoma                                              -0.113779
#  B-Lymphoblastic Leukemia/Lymphoma                              0.481205
#  Acute Myeloid Leukemia                                         0.172351
#  Ewing Sarcoma                                                 -0.020921
#  Neuroblastoma                                                 -0.002403
#  Synovial Sarcoma                                               0.047909
#  adeno                                                         -0.109422
#  Hepatocellular Carcinoma                                       0.025790
#  Adrenocortical Carcinoma                                       0.048890
#  Colon Adenocarcinoma                                           0.057125
#  Lung Adenocarcinoma                                            0.008915
#  Cutaneous Melanoma                                            -0.081043
#  Leiomyosarcoma                                                 0.025679
#  Renal Cell Carcinoma                                          -0.080607
#  Prostate Adenocarcinoma                                       -0.013378
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.056928
#  Invasive Breast Carcinoma                                     -0.000418
#  squamous                                                      -0.003449
#  Serous Ovarian Cancer                                         -0.042846
#  Thymoma                                                        0.037405
#  Wilms' Tumor                                                   0.084012
#  Papillary Thyroid Cancer                                       0.044890
#  Bladder Urothelial Carcinoma                                  -0.028367
#  Pleural Mesothelioma, Epithelioid Type                        -0.007694
#  Uterine Endometrioid Carcinoma                                 0.063802
#  Uveal Melanoma                                                 0.165996
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...            -0.017586
#  Chromophobe Renal Cell Carcinoma                              -0.006057
#  Intrahepatic Cholangiocarcinoma                                0.036548
#  Diffuse Large B-Cell Lymphoma, NOS                             0.048918
#
#                                                      TARGET-10-PAMXSP-09  \
#  CNS/Brain                                                     -0.052952
#  Osteosarcoma                                                  -0.011953
#  Medulloblastoma                                               -0.007047
#  Acute Megakaryoblastic Leukemia                                0.050897
#  acute lymphoblastic leukemia                                   0.160698
#  Rhabdomyosarcoma                                              -0.089287
#  B-Lymphoblastic Leukemia/Lymphoma                              0.477218
#  Acute Myeloid Leukemia                                         0.173085
#  Ewing Sarcoma                                                 -0.034191
#  Neuroblastoma                                                  0.003677
#  Synovial Sarcoma                                               0.008813
#  adeno                                                         -0.078986
#  Hepatocellular Carcinoma                                       0.033751
#  Adrenocortical Carcinoma                                       0.028583
#  Colon Adenocarcinoma                                           0.025151
#  Lung Adenocarcinoma                                            0.016456
#  Cutaneous Melanoma                                            -0.039281
#  Leiomyosarcoma                                                 0.031203
#  Renal Cell Carcinoma                                          -0.073219
#  Prostate Adenocarcinoma                                       -0.023205
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.092438
#  Invasive Breast Carcinoma                                     -0.000607
#  squamous                                                       0.009298
#  Serous Ovarian Cancer                                         -0.025182
#  Thymoma                                                        0.026431
#  Wilms' Tumor                                                   0.064194
#  Papillary Thyroid Cancer                                       0.052886
#  Bladder Urothelial Carcinoma                                  -0.013474
#  Pleural Mesothelioma, Epithelioid Type                         0.005991
#  Uterine Endometrioid Carcinoma                                 0.062860
#  Uveal Melanoma                                                 0.140536
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...            -0.011068
#  Chromophobe Renal Cell Carcinoma                               0.006239
#  Intrahepatic Cholangiocarcinoma                                0.029380
#  Diffuse Large B-Cell Lymphoma, NOS                             0.024448
#
#                                                      TARGET-10-PANCVR-03  \
#  CNS/Brain                                                     -0.070142
#  Osteosarcoma                                                  -0.036194
#  Medulloblastoma                                               -0.002798
#  Acute Megakaryoblastic Leukemia                                0.085811
#  acute lymphoblastic leukemia                                   0.133412
#  Rhabdomyosarcoma                                              -0.102817
#  B-Lymphoblastic Leukemia/Lymphoma                              0.447773
#  Acute Myeloid Leukemia                                         0.112464
#  Ewing Sarcoma                                                 -0.038599
#  Neuroblastoma                                                  0.010545
#  Synovial Sarcoma                                               0.055359
#  adeno                                                         -0.086753
#  Hepatocellular Carcinoma                                       0.025805
#  Adrenocortical Carcinoma                                       0.048642
#  Colon Adenocarcinoma                                           0.054222
#  Lung Adenocarcinoma                                           -0.018234
#  Cutaneous Melanoma                                            -0.088060
#  Leiomyosarcoma                                                -0.009612
#  Renal Cell Carcinoma                                          -0.110008
#  Prostate Adenocarcinoma                                       -0.009756
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.077382
#  Invasive Breast Carcinoma                                     -0.008924
#  squamous                                                      -0.020021
#  Serous Ovarian Cancer                                         -0.011304
#  Thymoma                                                        0.046127
#  Wilms' Tumor                                                   0.069156
#  Papillary Thyroid Cancer                                       0.061319
#  Bladder Urothelial Carcinoma                                  -0.013017
#  Pleural Mesothelioma, Epithelioid Type                         0.006052
#  Uterine Endometrioid Carcinoma                                 0.089129
#  Uveal Melanoma                                                 0.188346
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...             0.014466
#  Chromophobe Renal Cell Carcinoma                               0.008949
#  Intrahepatic Cholangiocarcinoma                                0.031746
#  Diffuse Large B-Cell Lymphoma, NOS                             0.078031
#
#                                                      TARGET-10-PANCVR-04  \
#  CNS/Brain                                                     -0.026510
#  Osteosarcoma                                                   0.069392
#  Medulloblastoma                                                0.002724
#  Acute Megakaryoblastic Leukemia                                0.074534
#  acute lymphoblastic leukemia                                   0.138843
#  Rhabdomyosarcoma                                              -0.056456
#  B-Lymphoblastic Leukemia/Lymphoma                              0.340739
#  Acute Myeloid Leukemia                                         0.160731
#  Ewing Sarcoma                                                 -0.023985
#  Neuroblastoma                                                 -0.011164
#  Synovial Sarcoma                                              -0.027479
#  adeno                                                         -0.017324
#  Hepatocellular Carcinoma                                       0.015283
#  Adrenocortical Carcinoma                                       0.058483
#  Colon Adenocarcinoma                                           0.030198
#  Lung Adenocarcinoma                                           -0.038335
#  Cutaneous Melanoma                                            -0.032646
#  Leiomyosarcoma                                                 0.011200
#  Renal Cell Carcinoma                                          -0.050747
#  Prostate Adenocarcinoma                                        0.040036
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.035197
#  Invasive Breast Carcinoma                                     -0.066723
#  squamous                                                       0.058269
#  Serous Ovarian Cancer                                         -0.044253
#  Thymoma                                                       -0.006312
#  Wilms' Tumor                                                   0.218395
#  Papillary Thyroid Cancer                                      -0.012548
#  Bladder Urothelial Carcinoma                                  -0.039156
#  Pleural Mesothelioma, Epithelioid Type                        -0.056177
#  Uterine Endometrioid Carcinoma                                 0.064723
#  Uveal Melanoma                                                 0.053247
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...             0.007799
#  Chromophobe Renal Cell Carcinoma                               0.016590
#  Intrahepatic Cholangiocarcinoma                                0.017353
#  Diffuse Large B-Cell Lymphoma, NOS                             0.113233
#
#                                                      TARGET-10-PANDWE-03  \
#  CNS/Brain                                                     -0.029762
#  Osteosarcoma                                                  -0.005373
#  Medulloblastoma                                               -0.004281
#  Acute Megakaryoblastic Leukemia                                0.122222
#  acute lymphoblastic leukemia                                   0.154846
#  Rhabdomyosarcoma                                              -0.103098
#  B-Lymphoblastic Leukemia/Lymphoma                              0.365124
#  Acute Myeloid Leukemia                                         0.218111
#  Ewing Sarcoma                                                 -0.074242
#  Neuroblastoma                                                  0.017868
#  Synovial Sarcoma                                               0.011343
#  adeno                                                          0.020085
#  Hepatocellular Carcinoma                                      -0.007625
#  Adrenocortical Carcinoma                                       0.016209
#  Colon Adenocarcinoma                                          -0.029763
#  Lung Adenocarcinoma                                            0.013600
#  Cutaneous Melanoma                                             0.005193
#  Leiomyosarcoma                                                -0.009995
#  Renal Cell Carcinoma                                          -0.012150
#  Prostate Adenocarcinoma                                        0.006170
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.069743
#  Invasive Breast Carcinoma                                      0.035329
#  squamous                                                       0.022954
#  Serous Ovarian Cancer                                         -0.024305
#  Thymoma                                                        0.010759
#  Wilms' Tumor                                                   0.080073
#  Papillary Thyroid Cancer                                       0.058293
#  Bladder Urothelial Carcinoma                                  -0.073750
#  Pleural Mesothelioma, Epithelioid Type                        -0.014601
#  Uterine Endometrioid Carcinoma                                 0.026405
#  Uveal Melanoma                                                 0.070042
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...            -0.000857
#  Chromophobe Renal Cell Carcinoma                               0.024392
#  Intrahepatic Cholangiocarcinoma                                0.001722
#  Diffuse Large B-Cell Lymphoma, NOS                             0.069389
#
#                                                      TARGET-10-PANEUH-09  \
#  CNS/Brain                                                     -0.044629
#  Osteosarcoma                                                   0.018587
#  Medulloblastoma                                                0.010062
#  Acute Megakaryoblastic Leukemia                                0.067649
#  acute lymphoblastic leukemia                                   0.138144
#  Rhabdomyosarcoma                                              -0.124928
#  B-Lymphoblastic Leukemia/Lymphoma                              0.440573
#  Acute Myeloid Leukemia                                         0.179507
#  Ewing Sarcoma                                                 -0.016973
#  Neuroblastoma                                                 -0.022116
#  Synovial Sarcoma                                               0.028965
#  adeno                                                         -0.058148
#  Hepatocellular Carcinoma                                       0.017538
#  Adrenocortical Carcinoma                                       0.046535
#  Colon Adenocarcinoma                                           0.050898
#  Lung Adenocarcinoma                                           -0.014166
#  Cutaneous Melanoma                                            -0.065920
#  Leiomyosarcoma                                                 0.026283
#  Renal Cell Carcinoma                                          -0.082847
#  Prostate Adenocarcinoma                                       -0.008034
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.064419
#  Invasive Breast Carcinoma                                      0.008486
#  squamous                                                       0.034468
#  Serous Ovarian Cancer                                         -0.104532
#  Thymoma                                                       -0.001500
#  Wilms' Tumor                                                   0.142674
#  Papillary Thyroid Cancer                                       0.052811
#  Bladder Urothelial Carcinoma                                  -0.014328
#  Pleural Mesothelioma, Epithelioid Type                        -0.009544
#  Uterine Endometrioid Carcinoma                                 0.044484
#  Uveal Melanoma                                                 0.121505
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...             0.019820
#  Chromophobe Renal Cell Carcinoma                               0.015022
#  Intrahepatic Cholangiocarcinoma                                0.013874
#  Diffuse Large B-Cell Lymphoma, NOS                             0.030691
#
#                                                      TARGET-10-PANFNZ-03  \
#  CNS/Brain                                                     -0.059959
#  Osteosarcoma                                                  -0.011086
#  Medulloblastoma                                               -0.016262
#  Acute Megakaryoblastic Leukemia                                0.124279
#  acute lymphoblastic leukemia                                   0.125405
#  Rhabdomyosarcoma                                              -0.123712
#  B-Lymphoblastic Leukemia/Lymphoma                              0.430641
#  Acute Myeloid Leukemia                                         0.205711
#  Ewing Sarcoma                                                 -0.032158
#  Neuroblastoma                                                  0.010883
#  Synovial Sarcoma                                               0.038864
#  adeno                                                         -0.101281
#  Hepatocellular Carcinoma                                       0.041207
#  Adrenocortical Carcinoma                                       0.053304
#  Colon Adenocarcinoma                                           0.062722
#  Lung Adenocarcinoma                                           -0.018839
#  Cutaneous Melanoma                                            -0.088328
#  Leiomyosarcoma                                                 0.006201
#  Renal Cell Carcinoma                                          -0.078907
#  Prostate Adenocarcinoma                                       -0.011781
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.075391
#  Invasive Breast Carcinoma                                     -0.011123
#  squamous                                                      -0.002753
#  Serous Ovarian Cancer                                         -0.038009
#  Thymoma                                                       -0.005734
#  Wilms' Tumor                                                   0.037583
#  Papillary Thyroid Cancer                                       0.067856
#  Bladder Urothelial Carcinoma                                  -0.029087
#  Pleural Mesothelioma, Epithelioid Type                         0.008294
#  Uterine Endometrioid Carcinoma                                 0.080548
#  Uveal Melanoma                                                 0.165477
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...             0.072753
#  Chromophobe Renal Cell Carcinoma                               0.015194
#  Intrahepatic Cholangiocarcinoma                                0.018845
#  Diffuse Large B-Cell Lymphoma, NOS                            -0.004370
#
#                                                      TARGET-10-PANGIF-03  \
#  CNS/Brain                                                     -0.030907
#  Osteosarcoma                                                  -0.025979
#  Medulloblastoma                                               -0.005222
#  Acute Megakaryoblastic Leukemia                                0.109685
#  acute lymphoblastic leukemia                                   0.161254
#  Rhabdomyosarcoma                                              -0.065489
#  B-Lymphoblastic Leukemia/Lymphoma                              0.459239
#  Acute Myeloid Leukemia                                         0.054113
#  Ewing Sarcoma                                                 -0.043885
#  Neuroblastoma                                                  0.050353
#  Synovial Sarcoma                                               0.031425
#  adeno                                                         -0.088442
#  Hepatocellular Carcinoma                                      -0.003512
#  Adrenocortical Carcinoma                                       0.038627
#  Colon Adenocarcinoma                                           0.076285
#  Lung Adenocarcinoma                                            0.000924
#  Cutaneous Melanoma                                            -0.071587
#  Leiomyosarcoma                                                 0.005672
#  Renal Cell Carcinoma                                          -0.089359
#  Prostate Adenocarcinoma                                       -0.043090
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.089329
#  Invasive Breast Carcinoma                                      0.027862
#  squamous                                                      -0.006892
#  Serous Ovarian Cancer                                         -0.013516
#  Thymoma                                                        0.026587
#  Wilms' Tumor                                                   0.107251
#  Papillary Thyroid Cancer                                       0.049173
#  Bladder Urothelial Carcinoma                                  -0.054768
#  Pleural Mesothelioma, Epithelioid Type                         0.004254
#  Uterine Endometrioid Carcinoma                                 0.068125
#  Uveal Melanoma                                                 0.163718
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...             0.044461
#  Chromophobe Renal Cell Carcinoma                               0.010327
#  Intrahepatic Cholangiocarcinoma                                0.060953
#  Diffuse Large B-Cell Lymphoma, NOS                            -0.030612
#
#                                                      TARGET-10-PANIEU-03  \
#  CNS/Brain                                                     -0.055440
#  Osteosarcoma                                                  -0.031830
#  Medulloblastoma                                               -0.031155
#  Acute Megakaryoblastic Leukemia                                0.041999
#  acute lymphoblastic leukemia                                   0.241480
#  Rhabdomyosarcoma                                              -0.082212
#  B-Lymphoblastic Leukemia/Lymphoma                              0.390111
#  Acute Myeloid Leukemia                                         0.142066
#  Ewing Sarcoma                                                 -0.016702
#  Neuroblastoma                                                  0.019543
#  Synovial Sarcoma                                               0.002597
#  adeno                                                         -0.096528
#  Hepatocellular Carcinoma                                       0.029060
#  Adrenocortical Carcinoma                                       0.051453
#  Colon Adenocarcinoma                                           0.052827
#  Lung Adenocarcinoma                                            0.005310
#  Cutaneous Melanoma                                            -0.081820
#  Leiomyosarcoma                                                 0.016219
#  Renal Cell Carcinoma                                          -0.067948
#  Prostate Adenocarcinoma                                       -0.005231
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.090809
#  Invasive Breast Carcinoma                                     -0.027376
#  squamous                                                      -0.018244
#  Serous Ovarian Cancer                                         -0.009442
#  Thymoma                                                        0.063847
#  Wilms' Tumor                                                   0.055876
#  Papillary Thyroid Cancer                                       0.060824
#  Bladder Urothelial Carcinoma                                  -0.010350
#  Pleural Mesothelioma, Epithelioid Type                         0.006094
#  Uterine Endometrioid Carcinoma                                 0.072943
#  Uveal Melanoma                                                 0.185348
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...             0.009794
#  Chromophobe Renal Cell Carcinoma                              -0.014815
#  Intrahepatic Cholangiocarcinoma                                0.036568
#  Diffuse Large B-Cell Lymphoma, NOS                             0.051584
#
#                                                      TARGET-10-PANJPG-09  ...  \
#  CNS/Brain                                                     -0.072011  ...
#  Osteosarcoma                                                  -0.031663  ...
#  Medulloblastoma                                               -0.002134  ...
#  Acute Megakaryoblastic Leukemia                                0.138614  ...
#  acute lymphoblastic leukemia                                   0.135249  ...
#  Rhabdomyosarcoma                                              -0.071496  ...
#  B-Lymphoblastic Leukemia/Lymphoma                              0.390504  ...
#  Acute Myeloid Leukemia                                         0.214336  ...
#  Ewing Sarcoma                                                 -0.034872  ...
#  Neuroblastoma                                                  0.029256  ...
#  Synovial Sarcoma                                              -0.010055  ...
#  adeno                                                         -0.091631  ...
#  Hepatocellular Carcinoma                                       0.043843  ...
#  Adrenocortical Carcinoma                                       0.034250  ...
#  Colon Adenocarcinoma                                           0.069497  ...
#  Lung Adenocarcinoma                                           -0.021876  ...
#  Cutaneous Melanoma                                            -0.038731  ...
#  Leiomyosarcoma                                                 0.013605  ...
#  Renal Cell Carcinoma                                          -0.065668  ...
#  Prostate Adenocarcinoma                                       -0.031781  ...
#  Uterine Serous Carcinoma/Uterine Papillary Sero...            -0.085607  ...
#  Invasive Breast Carcinoma                                      0.006514  ...
#  squamous                                                      -0.016845  ...
#  Serous Ovarian Cancer                                          0.028941  ...
#  Thymoma                                                        0.044620  ...
#  Wilms' Tumor                                                   0.004067  ...
#  Papillary Thyroid Cancer                                       0.039679  ...
#  Bladder Urothelial Carcinoma                                  -0.019284  ...
#  Pleural Mesothelioma, Epithelioid Type                         0.015225  ...
#  Uterine Endometrioid Carcinoma                                 0.110448  ...
# ...
#  Osteosarcoma                                              0.012266
#  Medulloblastoma                                           0.098598
#  Acute Megakaryoblastic Leukemia                           0.074411
#  acute lymphoblastic leukemia                             -0.010578
#  Rhabdomyosarcoma                                         -0.146518
#  B-Lymphoblastic Leukemia/Lymphoma                         0.077089
#  Acute Myeloid Leukemia                                   -0.054590
#  Ewing Sarcoma                                            -0.032375
#  Neuroblastoma                                            -0.017800
#  Synovial Sarcoma                                          0.122861
#  adeno                                                    -0.042814
#  Hepatocellular Carcinoma                                  0.009421
#  Adrenocortical Carcinoma                                  0.085071
#  Colon Adenocarcinoma                                      0.041060
#  Lung Adenocarcinoma                                       0.014543
#  Cutaneous Melanoma                                        0.030683
#  Leiomyosarcoma                                            0.045471
#  Renal Cell Carcinoma                                     -0.041224
#  Prostate Adenocarcinoma                                   0.001301
#  Uterine Serous Carcinoma/Uterine Papillary Sero...       -0.096698
#  Invasive Breast Carcinoma                                 0.075398
#  squamous                                                 -0.047338
#  Serous Ovarian Cancer                                    -0.023407
#  Thymoma                                                  -0.091469
#  Wilms' Tumor                                              0.117548
#  Papillary Thyroid Cancer                                  0.020303
#  Bladder Urothelial Carcinoma                             -0.068139
#  Pleural Mesothelioma, Epithelioid Type                    0.013029
#  Uterine Endometrioid Carcinoma                           -0.054110
#  Uveal Melanoma                                            0.108680
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...        0.017955
#  Chromophobe Renal Cell Carcinoma                          0.056984
#  Intrahepatic Cholangiocarcinoma                           0.032890
#  Diffuse Large B-Cell Lymphoma, NOS                       -0.066999
#
#                                                      THR37_1308_S01  \
#  CNS/Brain                                                 0.200990
#  Osteosarcoma                                              0.009644
#  Medulloblastoma                                           0.193816
#  Acute Megakaryoblastic Leukemia                           0.027525
#  acute lymphoblastic leukemia                             -0.012196
#  Rhabdomyosarcoma                                         -0.092214
#  B-Lymphoblastic Leukemia/Lymphoma                         0.041998
#  Acute Myeloid Leukemia                                    0.015404
#  Ewing Sarcoma                                            -0.004515
#  Neuroblastoma                                            -0.106962
#  Synovial Sarcoma                                          0.068361
#  adeno                                                    -0.080437
#  Hepatocellular Carcinoma                                  0.104538
#  Adrenocortical Carcinoma                                  0.036657
#  Colon Adenocarcinoma                                     -0.015696
#  Lung Adenocarcinoma                                       0.039652
#  Cutaneous Melanoma                                        0.040886
#  Leiomyosarcoma                                            0.021115
#  Renal Cell Carcinoma                                      0.046268
#  Prostate Adenocarcinoma                                   0.037536
#  Uterine Serous Carcinoma/Uterine Papillary Sero...       -0.016893
#  Invasive Breast Carcinoma                                 0.068155
#  squamous                                                 -0.055162
#  Serous Ovarian Cancer                                     0.117116
#  Thymoma                                                  -0.018493
#  Wilms' Tumor                                              0.038900
#  Papillary Thyroid Cancer                                  0.052273
#  Bladder Urothelial Carcinoma                             -0.044264
#  Pleural Mesothelioma, Epithelioid Type                    0.032699
#  Uterine Endometrioid Carcinoma                            0.065554
#  Uveal Melanoma                                            0.023848
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...       -0.040669
#  Chromophobe Renal Cell Carcinoma                          0.058315
#  Intrahepatic Cholangiocarcinoma                          -0.081766
#  Diffuse Large B-Cell Lymphoma, NOS                        0.051101
#
#                                                      THR39_1362_S01  \
#  CNS/Brain                                                 0.074659
#  Osteosarcoma                                             -0.012937
#  Medulloblastoma                                           0.041550
#  Acute Megakaryoblastic Leukemia                           0.039724
#  acute lymphoblastic leukemia                             -0.009235
#  Rhabdomyosarcoma                                         -0.076679
#  B-Lymphoblastic Leukemia/Lymphoma                         0.034045
#  Acute Myeloid Leukemia                                   -0.053907
#  Ewing Sarcoma                                             0.024962
#  Neuroblastoma                                            -0.017795
#  Synovial Sarcoma                                          0.584337
#  adeno                                                    -0.060762
#  Hepatocellular Carcinoma                                 -0.017795
#  Adrenocortical Carcinoma                                  0.086266
#  Colon Adenocarcinoma                                      0.111463
#  Lung Adenocarcinoma                                      -0.017089
#  Cutaneous Melanoma                                       -0.059475
#  Leiomyosarcoma                                           -0.027978
#  Renal Cell Carcinoma                                     -0.047590
#  Prostate Adenocarcinoma                                   0.039366
#  Uterine Serous Carcinoma/Uterine Papillary Sero...        0.013808
#  Invasive Breast Carcinoma                                -0.027735
#  squamous                                                 -0.043166
#  Serous Ovarian Cancer                                     0.018083
#  Thymoma                                                  -0.002858
#  Wilms' Tumor                                              0.088950
#  Papillary Thyroid Cancer                                  0.037438
#  Bladder Urothelial Carcinoma                              0.033872
#  Pleural Mesothelioma, Epithelioid Type                   -0.000127
#  Uterine Endometrioid Carcinoma                            0.023273
#  Uveal Melanoma                                            0.076480
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...        0.067817
#  Chromophobe Renal Cell Carcinoma                          0.043432
#  Intrahepatic Cholangiocarcinoma                           0.040334
#  Diffuse Large B-Cell Lymphoma, NOS                       -0.073740
#
#                                                      THR39_1369_S01  \
#  CNS/Brain                                                 0.018413
#  Osteosarcoma                                              0.045628
#  Medulloblastoma                                           0.040588
#  Acute Megakaryoblastic Leukemia                           0.083385
#  acute lymphoblastic leukemia                             -0.005005
#  Rhabdomyosarcoma                                         -0.049693
#  B-Lymphoblastic Leukemia/Lymphoma                         0.064093
#  Acute Myeloid Leukemia                                   -0.028315
#  Ewing Sarcoma                                             0.030901
#  Neuroblastoma                                            -0.022117
#  Synovial Sarcoma                                          0.671047
#  adeno                                                    -0.117072
#  Hepatocellular Carcinoma                                 -0.004907
#  Adrenocortical Carcinoma                                  0.077908
#  Colon Adenocarcinoma                                      0.094652
#  Lung Adenocarcinoma                                      -0.040265
#  Cutaneous Melanoma                                       -0.080418
#  Leiomyosarcoma                                            0.082781
#  Renal Cell Carcinoma                                     -0.047154
#  Prostate Adenocarcinoma                                   0.013236
#  Uterine Serous Carcinoma/Uterine Papillary Sero...       -0.033026
#  Invasive Breast Carcinoma                                -0.014599
#  squamous                                                 -0.064513
#  Serous Ovarian Cancer                                    -0.056252
#  Thymoma                                                  -0.011871
#  Wilms' Tumor                                              0.126154
#  Papillary Thyroid Cancer                                  0.041963
#  Bladder Urothelial Carcinoma                             -0.010584
#  Pleural Mesothelioma, Epithelioid Type                    0.027549
#  Uterine Endometrioid Carcinoma                           -0.018929
#  Uveal Melanoma                                            0.110509
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...       -0.015774
#  Chromophobe Renal Cell Carcinoma                          0.043163
#  Intrahepatic Cholangiocarcinoma                           0.035037
#  Diffuse Large B-Cell Lymphoma, NOS                       -0.081906
#
#                                                      THR39_1376_S01  \
#  CNS/Brain                                                -0.054261
#  Osteosarcoma                                              0.028685
#  Medulloblastoma                                           0.004264
#  Acute Megakaryoblastic Leukemia                           0.036527
#  acute lymphoblastic leukemia                              0.009507
#  Rhabdomyosarcoma                                          0.046926
#  B-Lymphoblastic Leukemia/Lymphoma                         0.074803
#  Acute Myeloid Leukemia                                    0.018583
#  Ewing Sarcoma                                             0.053067
#  Neuroblastoma                                             0.003718
#  Synovial Sarcoma                                          0.533693
#  adeno                                                    -0.147411
#  Hepatocellular Carcinoma                                  0.010945
#  Adrenocortical Carcinoma                                  0.081781
#  Colon Adenocarcinoma                                      0.135906
#  Lung Adenocarcinoma                                      -0.007745
#  Cutaneous Melanoma                                       -0.056524
#  Leiomyosarcoma                                            0.028472
#  Renal Cell Carcinoma                                     -0.039198
#  Prostate Adenocarcinoma                                  -0.043274
#  Uterine Serous Carcinoma/Uterine Papillary Sero...       -0.061784
#  Invasive Breast Carcinoma                                 0.030270
#  squamous                                                 -0.084643
#  Serous Ovarian Cancer                                    -0.017414
#  Thymoma                                                   0.010411
#  Wilms' Tumor                                              0.088048
#  Papillary Thyroid Cancer                                  0.018832
#  Bladder Urothelial Carcinoma                             -0.029525
#  Pleural Mesothelioma, Epithelioid Type                    0.010159
#  Uterine Endometrioid Carcinoma                            0.055571
#  Uveal Melanoma                                            0.188238
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...       -0.044552
#  Chromophobe Renal Cell Carcinoma                         -0.005085
#  Intrahepatic Cholangiocarcinoma                           0.028840
#  Diffuse Large B-Cell Lymphoma, NOS                        0.012661
#
#                                                      THR39_1378_S01
#  CNS/Brain                                                -0.050131
#  Osteosarcoma                                             -0.002088
#  Medulloblastoma                                           0.060575
#  Acute Megakaryoblastic Leukemia                          -0.010107
#  acute lymphoblastic leukemia                             -0.028293
#  Rhabdomyosarcoma                                         -0.012202
#  B-Lymphoblastic Leukemia/Lymphoma                         0.063219
#  Acute Myeloid Leukemia                                    0.031368
#  Ewing Sarcoma                                            -0.004996
#  Neuroblastoma                                             0.034043
#  Synovial Sarcoma                                          0.565015
#  adeno                                                    -0.091846
#  Hepatocellular Carcinoma                                  0.030272
#  Adrenocortical Carcinoma                                  0.109140
#  Colon Adenocarcinoma                                     -0.026711
#  Lung Adenocarcinoma                                      -0.083799
#  Cutaneous Melanoma                                       -0.135941
#  Leiomyosarcoma                                            0.036687
#  Renal Cell Carcinoma                                     -0.033460
#  Prostate Adenocarcinoma                                  -0.018264
#  Uterine Serous Carcinoma/Uterine Papillary Sero...        0.017422
#  Invasive Breast Carcinoma                                -0.035903
#  squamous                                                 -0.114723
#  Serous Ovarian Cancer                                    -0.013542
#  Thymoma                                                   0.049363
#  Wilms' Tumor                                              0.008500
#  Papillary Thyroid Cancer                                  0.074677
#  Bladder Urothelial Carcinoma                              0.060943
#  Pleural Mesothelioma, Epithelioid Type                   -0.000211
#  Uterine Endometrioid Carcinoma                            0.108562
#  Uveal Melanoma                                            0.215182
#  Uterine Carcinosarcoma/Uterine Malignant Mixed ...        0.062906
#  Chromophobe Renal Cell Carcinoma                         -0.010845
#  Intrahepatic Cholangiocarcinoma                           0.007359
#  Diffuse Large B-Cell Lymphoma, NOS                        0.014064
#
#  [35 rows x 10478 columns],
#  array([[ 1.26599814e-04, -3.27641396e-06, -8.85454844e-05, ...,
#          -5.64002898e-05, -6.76112415e-05, -3.36728640e-05],
#         [ 9.72806618e-05, -2.44771495e-04,  9.73067872e-07, ...,
#          -1.74705767e-05, -2.26960068e-05,  1.21299922e-05],
#         [-3.34925932e-05, -4.58567734e-05, -1.29074136e-05, ...,
#           1.06133996e-05,  1.28177777e-05, -2.76025488e-05],
#         ...,
#         [ 3.37934671e-05,  1.09765452e-04,  4.31394950e-05, ...,
#           9.87320808e-06,  8.79643361e-05, -9.17233583e-06],
#         [ 1.70121086e-04, -3.71431817e-04, -4.27512471e-05, ...,
#           1.95159583e-05, -1.88241400e-04, -3.90161154e-05],
#         [-1.44018481e-04,  4.61589738e-05,  2.65964806e-05, ...,
#          -3.65410783e-05,  2.27243677e-05,  4.78490255e-05]]))

# %%
"""performs an iterative process to train the classifier, calculate the accuracy for different subtypes based on top predictions, 
and store the results in a dictionary."""
acc_dict = dict()
sample_sizes = [25]
for ssize in sample_sizes:
    
    
    accuracy_list = []
    for i in range(5):
        classifier = get_tcga_classifier_bysubtype(ssize) 
        train_ids, accuracies, test_labels, projections, eta = classifier.train()
        score_data=projections, eta
        Top_score=score_data[0].apply(lambda x: x.sort_values(ascending=False).iloc[:3].index,axis = 0)
        data=Top_score.T
        df=tcga_meta[['sampleID','new_subtype']] 
        table=pd.merge(data,df, right_on='sampleID', left_index=True)
        #table = pd.merge(df, data, left_on='sampleID', right_index=True)
        grouped=table.groupby(['new_subtype'])
        
        accuracy=grouped.apply(lambda _df: _df.apply(lambda row:row.new_subtype in row.loc[[0,1,2]].tolist(),axis=1).mean())
        #print("The Standard Deviation of the thth accuracy is",accuracy.std())
        accuracy=pd.DataFrame(accuracy)
        accuracy.apply(lambda x: x.sort_values(ascending=False),axis = 0)
        accuracy_list.append(accuracy)
    acc_dict[ssize] = accuracy_list

# %%
classifier.markers.value_counts()

# %%
# Reset the index for each DataFrame in the list `acc_dict[25]`
dfs = [s.reset_index() for s in acc_dict[25]]

# Concatenate all DataFrames in the list `dfs` into a single DataFrame
combined_acc_df = pd.concat(dfs, ignore_index=True)

# Rename the columns of the combined DataFrame
combined_acc_df.columns = ['new_subtype', 'value']

# %%
def top_common_subtypes(df):
    """gets the 3 most common subtypes predicted for each subtype"""
    
    subtypes =df.loc[:, [0,1,2]].values.flatten()  
    subtypes = pd.DataFrame(subtypes, columns=['top_subtypes'])
    top3 = subtypes['top_subtypes'].value_counts().head(3)
    return top3
    
topsubtype=[]
for subtype in table.new_subtype.unique():
    subtype_df =table[table['new_subtype'] == subtype]
    top_df = top_common_subtypes(subtype_df)
    topsubtype.append((subtype, top_df))

# %%
# Concatenate DataFrames for each subtype into a single DataFrame
pair_df = pd.concat([pd.concat({topsubtype[i][0]: pd.DataFrame(data=topsubtype[i][1])}, names=['annotated_subtype']) for i in range(len(topsubtype))])

# %%
def get_pair(correlationdata, filtereddata, subtypes):
    """
    Generates pairs of subtypes and their corresponding correlation matrices.

    Parameters:
    - correlationdata (pd.DataFrame): DataFrame with correlation values between samples.
    - filtereddata (pd.DataFrame): DataFrame with filtered sample data.
    - subtypes (list): List of subtype names.

    Returns:
    - list: A list of tuples where each tuple contains two subtypes and their correlation matrix.
    """
    subtype_pairs = []
    first_subtype = subtypes[0]  # Use the first subtype as the reference for comparisons
    
    for subtype2 in subtypes:
        # Get the sample IDs for the current subtype and the reference subtype
        samples1 = filtereddata[filtereddata['new_subtype'] == first_subtype]['sampleID']
        samples2 = filtereddata[filtereddata['new_subtype'] == subtype2]['sampleID']
        
        # Extract the correlation matrix for the pair of subtypes
        comparison = correlationdata.loc[samples1, samples2]
        
        # Append the subtype pair and their correlation matrix to the list
        subtype_pairs.append((first_subtype, subtype2, comparison))
    
    return subtype_pairs

def get_pair_stat(subtype_pairs, correlation_data, filtered_data):
    """
    Computes the median correlation for each pair of subtypes.

    Parameters:
    - subtype_pairs (list): List of tuples containing subtype pairs and their correlation matrices.
    - correlation_data (pd.DataFrame): DataFrame with correlation values between samples.
    - filtered_data (pd.DataFrame): DataFrame with filtered sample data.

    Returns:
    - pd.DataFrame: DataFrame with subtype pairs and their median correlation values.
    """
    results = []
    
    for subtype1, subtype2, comparison in subtype_pairs:
        if not comparison.empty:
            if subtype1 == subtype2:
                # Compute median correlation for the lower triangle of the matrix if subtypes are the same
                tril = np.tril_indices(len(comparison), -1)
                median_corr = np.median(comparison.to_numpy()[tril])
            else:
                # Compute median correlation for the entire matrix if subtypes are different
                median_corr = np.median(comparison.to_numpy().flatten())
        
            # Append the result as a tuple (subtype1, subtype2, median_correlation) to the results list
            results.append((subtype1, subtype2, median_corr))
        else:
            # If the comparison matrix is empty, append NaNs for median correlation
            results.append((subtype1, subtype2, float('nan'), float('nan')))

    # Convert the results list to a DataFrame with specified column names
    return pd.DataFrame(results, columns=['col1', 'col2', 'median_correlation'])
    
Dataf=pair_df.reset_index()
def get_substat(subtype, Data):
    """
    Gets statistics for a given subtype including top subtypes, correlation data, and median correlations.

    Parameters:
    - subtype (str): The subtype for which statistics are being computed.
    - Data (pd.DataFrame): DataFrame containing annotated_subtype and its top3 subtypes.

    Returns:
    - pd.DataFrame: DataFrame with statistics for the given subtype.
    """
    print(f"Getting top subtypes for {subtype}")
    # Filter the data for the given subtype and get unique levels
    topsubtypes = Data[Data.annotated_subtype == subtype].level_1.unique()
    
    # Filter tcga_meta DataFrame to include only the top subtypes
    filtered_data = tcga_meta[tcga_meta['new_subtype'].isin(topsubtypes)]
    
    print("Getting correlation data")
    # Compute correlation matrix from classifier's expression data for the filtered samples
    correlation_data = classifier.expr.loc[filtered_data['sampleID']].T.corr()
    
    # Get pairs of subtypes and their correlation matrices
    pair = get_pair(correlation_data, filtered_data, topsubtypes)
    print(f"Number of subtypes processed: {len(subtype)}")

    print('Getting statistics')
    # Compute median correlations for the subtype pairs
    stat = get_pair_stat(pair, correlation_data, filtered_data)
    
    return pd.DataFrame(stat)

# %%
subtype_table=[]
for subtype in Data.annotated_subtype.unique():
    subtype_df=get_substat(subtype, Data)
    subtype_table.append(subtype_df)

# %%
df_sub_corr = pd.concat(subtype_table)
df_sub_corr.rename(columns={'col1':'annotated_subtype','col2':'top3'}, inplace=True)
df_sub_corr.to_csv('/Users/nabdirah/Project1/newsub_correlation.csv')

# %%
# for each annotated_subtype find the score the model gave to its top3 subtypes 
def get_subtypescore(subtype):
    """Parameters:
    - subtype (str): The subtype for which to calculate the scores.

    Returns:
    - pd.Series: A Series with the average score for each sample in the subset.
    """
    print(subtype)
    sample_set_bl = classifier.markers[classifier.markers == subtype].index
    print(sample_set_bl)
    subset = projections.loc[pair_df.loc[(subtype,),:].index,(sample_set_bl).intersection(projections.columns.tolist())]
    print(subset)
    Aug_score =subset.mean(axis=1)
    return Aug_score
subscore_df=[]
for subtype in classifier.markers.unique():
    subscore=get_subtypescore(subtype)
    subscore_df.append((subtype, subscore))

# %%
#Concatenate all the subtypes and their scores into a single DataFrame
score_df = pd.concat([pd.concat({subscore_df[i][0]: pd.DataFrame(data=subscore_df[i][1])}, names=['annotated_subtype']) for i in range(len(subscore_df))])

# %%
score_df=score_df.reset_index()
score_df.rename(columns={'level_1': 'top3', 0:'score'}, inplace=True)
score_df

# %%
#merge the Dataframes with scores and median correlation 
merged_dfs=pd.merge(score_df,df_sub_corr,left_on=['annotated_subtype','top3'],right_on=['annotated_subtype','top3'])

# %%
#save
merged_dfs.to_csv('/Users/nabdirah/Project1/correlationscore.csv')
merged_dfs.drop(columns='level_0')
merged_dfs.set_index('annotated_subtype')
merged_dfs = merged_dfs.drop(columns=['level_0', 'index'])
merged_dfs.rename(columns={0:'score'}, inplace=True)
merged_dfs=merged_dfs.drop_duplicates()
merged_dfs.to_csv('/Users/nabdirah/Project1/Fixed_data.csv')

# %%
# list of value counts for the different subtypes we have at this point
subtpe_count=[merged_dfs['annotated_subtype'].value_counts()]
subtpe_count
